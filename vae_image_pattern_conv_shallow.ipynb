# %%
from PIL import Image
from pillow_heif import register_heif_opener
import torch
import torch.nn.functional as F
import numpy as np
import torchvision.transforms as transforms
import time
import random

torch.manual_seed(112916)

register_heif_opener()

image = Image.open('data/IMG_1432.HEIC')

print(image.size)
print(image.mode)
# Out:
# (1018, 240)
# RGB

# %%
DEVICE = 'mps' if torch.backends.mps.is_available() else 'cuda'

transform = transforms.Compose([ 
    transforms.PILToTensor() 
])

img_tensor = transform(image)
img_tensor = img_tensor.to(torch.float) / 255.0

# clip the bottom and right 1-pixel edge as it contains random grey pixels (compression artifact?)
img_tensor = img_tensor[:, :, :-1]

print(img_tensor.shape)
# Out:
# torch.Size([3, 240, 1017])

# %%
IMAGE_CHANNELS = 3
SLICES = 50

# calculate slice width
slice_width = img_tensor.shape[2] // SLICES
slice_height = img_tensor.shape[1]
slice_shape = (IMAGE_CHANNELS, slice_height, slice_width)
# note that we are no longer flattening the slices because our 2D inputs will go
# to a conv layer

hidden_size = 256
latent_size = 128
conv_1_out = 64
conv_2_out = 128
conv_3_out = 256

slice_hw_ratio = slice_height//slice_width

print(f'Slice Shape: {slice_shape}')
print(f'Slice H/W Ratio: {slice_hw_ratio}')
# Out:
# Slice Shape: (3, 240, 20)
# Slice H/W Ratio: 12

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

def visualize_feature_maps(layer_output, num_feature_maps=10, cols=5):
    """
    Visualizes feature maps from a given layer output.

    Args:
    - layer_output (torch.Tensor): The output tensor from the layer you wish to visualize.
                                   Shape should be [N, C, H, W] (batch size, number of channels, height, width).
    - num_feature_maps (int): Number of feature maps to visualize. Default is 10.
    - cols (int): Number of columns in the subplot grid. Default is 5.
    """
    # Ensure layer_output is on CPU and detached from the computation graph
    feature_maps = layer_output[0].detach().cpu()

    # Determine the number of rows needed in the subplot grid
    rows = num_feature_maps // cols + int(num_feature_maps % cols != 0)

    # Set up the figure size and grid for plots
    fig, axes = plt.subplots(rows, cols, figsize=(cols, rows * 2.5))
    axes = axes.flatten()  # Flatten the axes array for easy iteration

    # Iterate and plot each feature map
    for i in range(num_feature_maps):
        if i < feature_maps.shape[0]:  # Check if the index is within the number of available feature maps
            # Access the feature map for the ith filter and convert to numpy
            feature_map = feature_maps[i].numpy()
            axes[i].imshow(feature_map, cmap='gray', aspect='auto')
            axes[i].axis('off')
            # axes[i].set_title(f'Feature Map {i+1}')
        else:
            axes[i].axis('off')  # Turn off axis for any unused subplot

    plt.tight_layout()
    plt.show()

# %%
# encoder portion. will take our slices and (learn to) encode them into the latent space
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        
        kernel_width = 3
        kernel_height = kernel_width * slice_hw_ratio
        
        self.conv1 = nn.Conv2d(in_channels=IMAGE_CHANNELS, out_channels=conv_1_out, kernel_size=3, 
                               stride=1, padding=1, padding_mode='zeros') # (conv_1_out, 1917, 81)
        self.conv2 = nn.Conv2d(in_channels=conv_1_out, out_channels=conv_2_out, kernel_size=3, 
                               stride=1, padding=1, padding_mode='zeros') # (conv_2_out, 1917, 81)
        self.conv3 = nn.Conv2d(in_channels=conv_2_out, out_channels=conv_3_out, kernel_size=3, 
                               stride=1, padding=1, padding_mode='zeros') # (conv_3_out, 1917, 81)
        self.pool1 = nn.MaxPool2d(kernel_size=3, stride=2) # (conv_3_out, 1917, 81)
        self.flatten = nn.Flatten() # (conv_3_out*957*39)
        self.norm1 = nn.LayerNorm([conv_3_out*119*9])
        self.relu = nn.LeakyReLU(0.2)
        self.linear = nn.Linear(conv_3_out*119*9, hidden_size)
        self.norm2 = nn.LayerNorm([hidden_size])
        self.mean = nn.Linear(hidden_size, latent_size)
        self.var = nn.Linear(hidden_size, latent_size)
        
    def forward(self, x):
        x = self.relu(self.conv1(x))
        #print(f'conv1 out shape: {x.shape}')
        x = self.relu(self.conv2(x))
        #print(f'conv2 out shape: {x.shape}')
        x = self.relu(self.conv3(x))
        #print(f'conv3 out shape: {x.shape}')
        x = self.pool1(x)
        #print(f'pool1 out shape: {x.shape}')
        x = self.flatten(x)
        x = self.relu(self.norm1(x))
        x = self.relu(self.norm2(self.linear(x)))
        
        mean = self.mean(x)
        log_variance = self.var(x)
        
        return mean, log_variance

class Upsample(nn.Module):
    def __init__(self, scale_factor, in_channels, out_channels, kernel_size, stride, padding, mode='nearest'):
        super(Upsample, self).__init__()
        self.scale_factor = scale_factor
        self.refine_conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.mode = mode

    def forward(self, x):
        x_upsampled = F.interpolate(x, scale_factor=self.scale_factor, mode=self.mode,
                                    align_corners=True if self.mode == 'bilinear' else None)
        return self.refine_conv(x_upsampled)

# decoder portion. takes data that is normally distributed in the latent space
# and decodes to the input space
class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        
        self.latent_in = nn.Linear(latent_size, hidden_size)
        self.hidden_layer = nn.Linear(hidden_size, conv_3_out*119*9)
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(conv_3_out,119,9))
        self.unpool = Upsample(mode='nearest', scale_factor=2, in_channels=conv_3_out, out_channels=conv_2_out,
                               kernel_size=3, stride=1, padding=2)
        self.unconv2 = nn.Conv2d(in_channels=conv_2_out, out_channels=conv_1_out, kernel_size=3, 
                               stride=1, padding=1, padding_mode='reflect')
        self.unconv1 = nn.Conv2d(in_channels=conv_1_out, out_channels=IMAGE_CHANNELS, kernel_size=3, 
                               stride=1, padding=1, padding_mode='reflect')
        
        self.norm1 = nn.LayerNorm([hidden_size])
        self.norm2 = nn.LayerNorm([conv_3_out*119*9])
        
        self.relu = nn.LeakyReLU(0.2)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        x = self.relu(self.norm1(self.latent_in(x)))
        x = self.relu(self.norm2(self.hidden_layer(x)))
        x = self.relu(self.unflatten(x))
        x = self.unpool(x)
        #visualize_feature_maps(x)
        #visualize_feature_maps(x)
        #print(f'uc3 shape: {x.shape}')
        x = self.unconv2(x)
        #print(f'uc2 shape: {x.shape}')
        x = self.unconv1(x)
        #print(f'uc1 shape: {x.shape}')
        x = self.sigmoid(x)
        
        return x
    
# puts it all together and adds the reparameterization trick to 
# establish the Gaussian distribution
class VAETrainingModel(nn.Module):
    def __init__(self, encoder, decoder):
        super(VAETrainingModel, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
    
    def reparameterize(self, mean, var):
        epsilon = torch.randn_like(var).to(DEVICE)
        return mean + epsilon * var
        
    def forward(self, x):
        mean, log_var = self.encoder(x)
        x = self.reparameterize(mean, log_var)
        x = self.decoder(x)
        
        return x, mean, log_var
    
def cost_function(x, x_pred, mean, log_var):
    #print(x.shape)
    #print(x_pred.shape)
    reproduction_loss = nn.functional.mse_loss(x_pred, x)
    KLD      = - 0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())

    return reproduction_loss + KLD

# %%
BATCH_SIZE = 15
EPOCH_ITERS = img_tensor.shape[2] // slice_width // BATCH_SIZE
MODEL_WEIGHTS_FILE = 'out/model_conv_shallow.pt'

# train the model on the flattened data
def train_model(model, next_batch, criterion, optimizer, scheduler, num_epochs=25):
    print(f'Model is training with {num_epochs} epochs with {EPOCH_ITERS} iterations per epoch')
    since = time.time()

    best_loss = np.inf
    best_epoch = 0

    phases = ['train', 'val']

    # Keep track of how loss evolves during training
    training_curves = {}
    for phase in phases:
        training_curves[phase+'_loss'] = []

    for epoch in range(num_epochs):
        print(f'\nEpoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0

            # iterate over enough batches to try to cover the entire image (1 epoch)
            for _ in range(EPOCH_ITERS):
                inputs = next_batch(BATCH_SIZE)
                # print('Batch is', inputs.shape[0])
                inputs = inputs.to(DEVICE)
                # our targets are the same as our inputs
                targets = inputs.to(DEVICE)
                # print(inputs.shape)
                # print(targets.shape)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                with torch.set_grad_enabled(phase == 'train'):
                    x_pred, mean, log_var = model(inputs)
                    # print(outputs.shape)
                    loss = criterion(targets, x_pred, mean, log_var)

                    # backward + update weights only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)

            if scheduler and phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / BATCH_SIZE
            training_curves[phase+'_loss'].append(epoch_loss)

            print(f'{phase:5} Loss: {epoch_loss:.4f}')

            # save the model if it's the best loss
            if phase == 'val' and epoch_loss < best_loss:
              best_epoch = epoch
              best_loss = epoch_loss
              with open(MODEL_WEIGHTS_FILE, 'wb') as f:
                torch.save(model.state_dict(), f)

    time_elapsed = time.time() - since
    print(f'\nTraining complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Loss: {best_loss:4f} at epoch {best_epoch}')

    # load best model weights
    model.load_state_dict(torch.load(MODEL_WEIGHTS_FILE, map_location=DEVICE))

    return model, training_curves

# %%
LEARNING_RATE = 1e-3

encoder = Encoder().to(DEVICE)
print('Encoder: ', sum(p.numel() for p in encoder.parameters())/1e6, 'M parameters')
decoder = Decoder().to(DEVICE)
print('Decoder: ', sum(p.numel() for p in decoder.parameters())/1e6, 'M parameters')
training_model = VAETrainingModel(encoder, decoder).to(DEVICE)

optimizer_ = torch.optim.AdamW(training_model.parameters(), lr=LEARNING_RATE)
scheduler_ = torch.optim.lr_scheduler.ExponentialLR(optimizer_, gamma=0.98)
# Out:
# Encoder:  71.174784 M parameters
# Decoder:  71.415683 M parameters

# %%
def get_batch(batch_size):
    """ Returns a batch consisting of batch_size slices of the training data """
    # our img_tensor is torch.Size([3, 1917, 8141])
    # so we want to start at a random spot in the tensor that is < slice_width
    # then take a slice_width chunk of the 3rd dimension which is the width
    
    # calculate the maximum start index for the width
    max_start_index_width = img_tensor.size(2) - slice_width

    batch_list = []
    for _ in range(batch_size):
        start = random.randint(0, max_start_index_width)
        img_slice = img_tensor[:, :, start:start + slice_width]
        #print(f'Random tensor of size {img_slice.shape} width at {start} ')
        batch_list.append(img_slice)
        
    ret = torch.stack(batch_list)
    #print(ret.shape)
    return ret

# %%
EPOCHS = 300
#train_model(training_model, get_batch, cost_function, optimizer_, scheduler_, EPOCHS)
train_model(training_model, get_batch, cost_function, optimizer_, None, EPOCHS)
# Out:
# Model is training with 300 epochs with 3 iterations per epoch
#
# Epoch 1/300
# ----------
# train Loss: 658.8431
# val   Loss: 237.6598
#
# Epoch 2/300
# ----------
# train Loss: 140.1887
# val   Loss: 50.9132
#
# Epoch 3/300
# ----------
# train Loss: 57.6445
# val   Loss: 75.2282
#
# Epoch 4/300
# ----------
# train Loss: 75.4218
# val   Loss: 64.0008
#
# Epoch 5/300
# ----------
# train Loss: 52.3549
# val   Loss: 31.9327
#
# Epoch 6/300
# ----------
# train Loss: 26.1923
# val   Loss: 18.6176
#
# Epoch 7/300
# ----------
# train Loss: 17.2878
# val   Loss: 15.8718
#
# Epoch 8/300
# ----------
# train Loss: 15.5743
# val   Loss: 14.3956
#
# Epoch 9/300
# ----------
# train Loss: 12.9806
# val   Loss: 9.9072
#
# Epoch 10/300
# ----------
# train Loss: 8.3304
# val   Loss: 5.7794
#
# Epoch 11/300
# ----------
# train Loss: 5.2002
# val   Loss: 4.7225
#
# Epoch 12/300
# ----------
# train Loss: 4.7188
# val   Loss: 4.3252
#
# Epoch 13/300
# ----------
# train Loss: 3.8679
# val   Loss: 2.8616
#
# Epoch 14/300
# ----------
# train Loss: 2.4121
# val   Loss: 1.9151
#
# Epoch 15/300
# ----------
# train Loss: 1.7735
# val   Loss: 1.5678
#
# Epoch 16/300
# ----------
# train Loss: 1.4820
# val   Loss: 1.2522
#
# Epoch 17/300
# ----------
# train Loss: 1.1345
# val   Loss: 0.8739
#
# Epoch 18/300
# ----------
# train Loss: 0.7829
# val   Loss: 0.6498
#
# Epoch 19/300
# ----------
# train Loss: 0.5993
# val   Loss: 0.5366
#
# Epoch 20/300
# ----------
# train Loss: 0.5004
# val   Loss: 0.3991
#
# Epoch 21/300
# ----------
# train Loss: 0.3763
# val   Loss: 0.2874
#
# Epoch 22/300
# ----------
# train Loss: 0.2834
# val   Loss: 0.2738
#
# Epoch 23/300
# ----------
# train Loss: 0.2542
# val   Loss: 0.2091
#
# Epoch 24/300
# ----------
# train Loss: 0.1787
# val   Loss: 0.1491
#
# Epoch 25/300
# ----------
# train Loss: 0.1568
# val   Loss: 0.1462
#
# Epoch 26/300
# ----------
# train Loss: 0.1329
# val   Loss: 0.1076
#
# Epoch 27/300
# ----------
# train Loss: 0.1257
# val   Loss: 0.0949
#
# Epoch 28/300
# ----------
# train Loss: 0.1017
# val   Loss: 0.0940
#
# Epoch 29/300
# ----------
# train Loss: 0.0957
# val   Loss: 0.0824
#
# Epoch 30/300
# ----------
# train Loss: 0.0896
# val   Loss: 0.0762
#
# Epoch 31/300
# ----------
# train Loss: 0.0711
# val   Loss: 0.0683
#
# Epoch 32/300
# ----------
# train Loss: 0.0842
# val   Loss: 0.0767
#
# Epoch 33/300
# ----------
# train Loss: 0.0596
# val   Loss: 0.0622
#
# Epoch 34/300
# ----------
# train Loss: 0.0601
# val   Loss: 0.0514
#
# Epoch 35/300
# ----------
# train Loss: 0.0562
# val   Loss: 0.0644
#
# Epoch 36/300
# ----------
# train Loss: 0.0701
# val   Loss: 0.0498
#
# Epoch 37/300
# ----------
# train Loss: 0.0642
# val   Loss: 0.0509
#
# Epoch 38/300
# ----------
# train Loss: 0.0620
# val   Loss: 0.0593
#
# Epoch 39/300
# ----------
# train Loss: 0.0589
# val   Loss: 0.0546
#
# Epoch 40/300
# ----------
# train Loss: 0.0529
# val   Loss: 0.0554
#
# Epoch 41/300
# ----------
# train Loss: 0.0479
# val   Loss: 0.0544
#
# Epoch 42/300
# ----------
# train Loss: 0.0520
# val   Loss: 0.0549
#
# Epoch 43/300
# ----------
# train Loss: 0.0558
# val   Loss: 0.0448
#
# Epoch 44/300
# ----------
# train Loss: 0.0509
# val   Loss: 0.0419
#
# Epoch 45/300
# ----------
# train Loss: 0.0545
# val   Loss: 0.0493
#
# Epoch 46/300
# ----------
# train Loss: 0.0511
# val   Loss: 0.0488
#
# Epoch 47/300
# ----------
# train Loss: 0.0467
# val   Loss: 0.0467
#
# Epoch 48/300
# ----------
# train Loss: 0.0437
# val   Loss: 0.0430
#
# Epoch 49/300
# ----------
# train Loss: 0.0469
# val   Loss: 0.0467
#
# Epoch 50/300
# ----------
# train Loss: 0.0532
# val   Loss: 0.0532
#
# Epoch 51/300
# ----------
# train Loss: 0.0434
# val   Loss: 0.0448
#
# Epoch 52/300
# ----------
# train Loss: 0.0519
# val   Loss: 0.0457
#
# Epoch 53/300
# ----------
# train Loss: 0.0493
# val   Loss: 0.0450
#
# Epoch 54/300
# ----------
# train Loss: 0.0448
# val   Loss: 0.0387
#
# Epoch 55/300
# ----------
# train Loss: 0.0416
# val   Loss: 0.0527
#
# Epoch 56/300
# ----------
# train Loss: 0.0440
# val   Loss: 0.0512
#
# Epoch 57/300
# ----------
# train Loss: 0.0426
# val   Loss: 0.0472
#
# Epoch 58/300
# ----------
# train Loss: 0.0443
# val   Loss: 0.0402
#
# Epoch 59/300
# ----------
# train Loss: 0.0406
# val   Loss: 0.0491
#
# Epoch 60/300
# ----------
# train Loss: 0.0434
# val   Loss: 0.0437
#
# Epoch 61/300
# ----------
# train Loss: 0.0467
# val   Loss: 0.0355
#
# Epoch 62/300
# ----------
# train Loss: 0.0402
# val   Loss: 0.0430
#
# Epoch 63/300
# ----------
# train Loss: 0.0420
# val   Loss: 0.0389
#
# Epoch 64/300
# ----------
# train Loss: 0.0449
# val   Loss: 0.0377
#
# Epoch 65/300
# ----------
# train Loss: 0.0387
# val   Loss: 0.0432
#
# Epoch 66/300
# ----------
# train Loss: 0.0350
# val   Loss: 0.0400
#
# Epoch 67/300
# ----------
# train Loss: 0.0413
# val   Loss: 0.0426
#
# Epoch 68/300
# ----------
# train Loss: 0.0438
# val   Loss: 0.0387
#
# Epoch 69/300
# ----------
# train Loss: 0.0407
# val   Loss: 0.0439
#
# Epoch 70/300
# ----------
# train Loss: 0.0424
# val   Loss: 0.0431
#
# Epoch 71/300
# ----------
# train Loss: 0.0447
# val   Loss: 0.0387
#
# Epoch 72/300
# ----------
# train Loss: 0.0399
# val   Loss: 0.0418
#
# Epoch 73/300
# ----------
# train Loss: 0.0392
# val   Loss: 0.0355
#
# Epoch 74/300
# ----------
# train Loss: 0.0392
# val   Loss: 0.0388
#
# Epoch 75/300
# ----------
# train Loss: 0.0365
# val   Loss: 0.0403
#
# Epoch 76/300
# ----------
# train Loss: 0.0416
# val   Loss: 0.0402
#
# Epoch 77/300
# ----------
# train Loss: 0.0395
# val   Loss: 0.0385
#
# Epoch 78/300
# ----------
# train Loss: 0.0405
# val   Loss: 0.0443
#
# Epoch 79/300
# ----------
# train Loss: 0.0417
# val   Loss: 0.0374
#
# Epoch 80/300
# ----------
# train Loss: 0.0367
# val   Loss: 0.0408
#
# Epoch 81/300
# ----------
# train Loss: 0.0406
# val   Loss: 0.0424
#
# Epoch 82/300
# ----------
# train Loss: 0.0462
# val   Loss: 0.0399
#
# Epoch 83/300
# ----------
# train Loss: 0.0416
# val   Loss: 0.0405
#
# Epoch 84/300
# ----------
# train Loss: 0.0369
# val   Loss: 0.0398
#
# Epoch 85/300
# ----------
# train Loss: 0.0378
# val   Loss: 0.0340
#
# Epoch 86/300
# ----------
# train Loss: 0.0374
# val   Loss: 0.0361
#
# Epoch 87/300
# ----------
# train Loss: 0.0394
# val   Loss: 0.0367
#
# Epoch 88/300
# ----------
# train Loss: 0.0350
# val   Loss: 0.0352
#
# Epoch 89/300
# ----------
# train Loss: 0.0347
# val   Loss: 0.0351
#
# Epoch 90/300
# ----------
# train Loss: 0.0371
# val   Loss: 0.0354
#
# Epoch 91/300
# ----------
# train Loss: 0.0375
# val   Loss: 0.0421
#
# Epoch 92/300
# ----------
# train Loss: 0.0339
# val   Loss: 0.0383
#
# Epoch 93/300
# ----------
# train Loss: 0.0384
# val   Loss: 0.0345
#
# Epoch 94/300
# ----------
# train Loss: 0.0350
# val   Loss: 0.0381
#
# Epoch 95/300
# ----------
# train Loss: 0.0335
# val   Loss: 0.0342
#
# Epoch 96/300
# ----------
# train Loss: 0.0337
# val   Loss: 0.0346
#
# Epoch 97/300
# ----------
# train Loss: 0.0341
# val   Loss: 0.0352
#
# Epoch 98/300
# ----------
# train Loss: 0.0339
# val   Loss: 0.0365
#
# Epoch 99/300
# ----------
# train Loss: 0.0399
# val   Loss: 0.0377
#
# Epoch 100/300
# ----------
# train Loss: 0.0371
# val   Loss: 0.0368
#
# Epoch 101/300
# ----------
# train Loss: 0.0393
# val   Loss: 0.0495
#
# Epoch 102/300
# ----------
# train Loss: 0.0434
# val   Loss: 0.0392
#
# Epoch 103/300
# ----------
# train Loss: 0.0450
# val   Loss: 0.0473
#
# Epoch 104/300
# ----------
# train Loss: 0.0432
# val   Loss: 0.0450
#
# Epoch 105/300
# ----------
# train Loss: 0.0394
# val   Loss: 0.0422
#
# Epoch 106/300
# ----------
# train Loss: 0.0351
# val   Loss: 0.0410
#
# Epoch 107/300
# ----------
# train Loss: 0.0429
# val   Loss: 0.0363
#
# Epoch 108/300
# ----------
# train Loss: 0.0375
# val   Loss: 0.0398
#
# Epoch 109/300
# ----------
# train Loss: 0.0399
# val   Loss: 0.0351
#
# Epoch 110/300
# ----------
# train Loss: 0.0347
# val   Loss: 0.0343
#
# Epoch 111/300
# ----------
# train Loss: 0.0347
# val   Loss: 0.0364
#
# Epoch 112/300
# ----------
# train Loss: 0.0356
# val   Loss: 0.0335
#
# Epoch 113/300
# ----------
# train Loss: 0.0374
# val   Loss: 0.0393
#
# Epoch 114/300
# ----------
# train Loss: 0.0389
# val   Loss: 0.0350
#
# Epoch 115/300
# ----------
# train Loss: 0.0380
# val   Loss: 0.0458
#
# Epoch 116/300
# ----------
# train Loss: 0.0380
# val   Loss: 0.0383
#
# Epoch 117/300
# ----------
# train Loss: 0.0391
# val   Loss: 0.0330
#
# Epoch 118/300
# ----------
# train Loss: 0.0381
# val   Loss: 0.0427
#
# Epoch 119/300
# ----------
# train Loss: 0.0413
# val   Loss: 0.0368
#
# Epoch 120/300
# ----------
# train Loss: 0.0361
# val   Loss: 0.0360
#
# Epoch 121/300
# ----------
# train Loss: 0.0346
# val   Loss: 0.0358
#
# Epoch 122/300
# ----------
# train Loss: 0.0343
# val   Loss: 0.0352
#
# Epoch 123/300
# ----------
# train Loss: 0.0352
# val   Loss: 0.0342
#
# Epoch 124/300
# ----------
# train Loss: 0.0332
# val   Loss: 0.0312
#
# Epoch 125/300
# ----------
# train Loss: 0.0356
# val   Loss: 0.0302
#
# Epoch 126/300
# ----------
# train Loss: 0.0321
# val   Loss: 0.0329
#
# Epoch 127/300
# ----------
# train Loss: 0.0316
# val   Loss: 0.0316
#
# Epoch 128/300
# ----------
# train Loss: 0.0328
# val   Loss: 0.0355
#
# Epoch 129/300
# ----------
# train Loss: 0.0370
# val   Loss: 0.0388
#
# Epoch 130/300
# ----------
# train Loss: 0.0382
# val   Loss: 0.0348
#
# Epoch 131/300
# ----------
# train Loss: 0.0363
# val   Loss: 0.0334
#
# Epoch 132/300
# ----------
# train Loss: 0.0312
# val   Loss: 0.0333
#
# Epoch 133/300
# ----------
# train Loss: 0.0359
# val   Loss: 0.0368
#
# Epoch 134/300
# ----------
# train Loss: 0.0336
# val   Loss: 0.0342
#
# Epoch 135/300
# ----------
# train Loss: 0.0332
# val   Loss: 0.0363
#
# Epoch 136/300
# ----------
# train Loss: 0.0334
# val   Loss: 0.0339
#
# Epoch 137/300
# ----------
# train Loss: 0.0347
# val   Loss: 0.0329
#
# Epoch 138/300
# ----------
# train Loss: 0.0331
# val   Loss: 0.0355
#
# Epoch 139/300
# ----------
# train Loss: 0.0331
# val   Loss: 0.0298
#
# Epoch 140/300
# ----------
# train Loss: 0.0316
# val   Loss: 0.0337
#
# Epoch 141/300
# ----------
# train Loss: 0.0315
# val   Loss: 0.0323
#
# Epoch 142/300
# ----------
# train Loss: 0.0331
# val   Loss: 0.0339
#
# Epoch 143/300
# ----------
# train Loss: 0.0334
# val   Loss: 0.0332
#
# Epoch 144/300
# ----------
# train Loss: 0.0323
# val   Loss: 0.0398
#
# Epoch 145/300
# ----------
# train Loss: 0.0349
# val   Loss: 0.0380
#
# Epoch 146/300
# ----------
# train Loss: 0.0394
# val   Loss: 0.0362
#
# Epoch 147/300
# ----------
# train Loss: 0.0395
# val   Loss: 0.0403
#
# Epoch 148/300
# ----------
# train Loss: 0.0446
# val   Loss: 0.0423
#
# Epoch 149/300
# ----------
# train Loss: 0.0399
# val   Loss: 0.0427
#
# Epoch 150/300
# ----------
# train Loss: 0.0431
# val   Loss: 0.0343
#
# Epoch 151/300
# ----------
# train Loss: 0.0391
# val   Loss: 0.0386
#
# Epoch 152/300
# ----------
# train Loss: 0.0375
# val   Loss: 0.0414
#
# Epoch 153/300
# ----------
# train Loss: 0.0378
# val   Loss: 0.0325
#
# Epoch 154/300
# ----------
# train Loss: 0.0363
# val   Loss: 0.0347
#
# Epoch 155/300
# ----------
# train Loss: 0.0348
# val   Loss: 0.0312
#
# Epoch 156/300
# ----------
# train Loss: 0.0324
# val   Loss: 0.0328
#
# Epoch 157/300
# ----------
# train Loss: 0.0363
# val   Loss: 0.0526
#
# Epoch 158/300
# ----------
# train Loss: 0.0523
# val   Loss: 0.0569
#
# Epoch 159/300
# ----------
# train Loss: 0.0515
# val   Loss: 0.0474
#
# Epoch 160/300
# ----------
# train Loss: 0.0430
# val   Loss: 0.0439
#
# Epoch 161/300
# ----------
# train Loss: 0.0425
# val   Loss: 0.0376
#
# Epoch 162/300
# ----------
# train Loss: 0.0375
# val   Loss: 0.0362
#
# Epoch 163/300
# ----------
# train Loss: 0.0348
# val   Loss: 0.0336
#
# Epoch 164/300
# ----------
# train Loss: 0.0380
# val   Loss: 0.0310
#
# Epoch 165/300
# ----------
# train Loss: 0.0344
# val   Loss: 0.0393
#
# Epoch 166/300
# ----------
# train Loss: 0.0403
# val   Loss: 0.0391
#
# Epoch 167/300
# ----------
# train Loss: 0.0391
# val   Loss: 0.0410
#
# Epoch 168/300
# ----------
# train Loss: 0.0357
# val   Loss: 0.0380
#
# Epoch 169/300
# ----------
# train Loss: 0.0359
# val   Loss: 0.0381
#
# Epoch 170/300
# ----------
# train Loss: 0.0359
# val   Loss: 0.0364
#
# Epoch 171/300
# ----------
# train Loss: 0.0374
# val   Loss: 0.0413
#
# Epoch 172/300
# ----------
# train Loss: 0.0363
# val   Loss: 0.0368
#
# Epoch 173/300
# ----------
# train Loss: 0.0340
# val   Loss: 0.0412
#
# Epoch 174/300
# ----------
# train Loss: 0.0365
# val   Loss: 0.0354
#
# Epoch 175/300
# ----------
# train Loss: 0.0411
# val   Loss: 0.0435
#
# Epoch 176/300
# ----------
# train Loss: 0.0436
# val   Loss: 0.0431
#
# Epoch 177/300
# ----------
# train Loss: 0.0386
# val   Loss: 0.0377
#
# Epoch 178/300
# ----------
# train Loss: 0.0414
# val   Loss: 0.0386
#
# Epoch 179/300
# ----------
# train Loss: 0.0400
# val   Loss: 0.0366
#
# Epoch 180/300
# ----------
# train Loss: 0.0388
# val   Loss: 0.0462
#
# Epoch 181/300
# ----------
# train Loss: 0.0438
# val   Loss: 0.0435
#
# Epoch 182/300
# ----------
# train Loss: 0.0436
# val   Loss: 0.0398
#
# Epoch 183/300
# ----------
# train Loss: 0.0363
# val   Loss: 0.0385
#
# Epoch 184/300
# ----------
# train Loss: 0.0362
# val   Loss: 0.0371
#
# Epoch 185/300
# ----------
# train Loss: 0.0371
# val   Loss: 0.0343
#
# Epoch 186/300
# ----------
# train Loss: 0.0335
# val   Loss: 0.0304
#
# Epoch 187/300
# ----------
# train Loss: 0.0355
# val   Loss: 0.0336
#
# Epoch 188/300
# ----------
# train Loss: 0.0341
# val   Loss: 0.0444
#
# Epoch 189/300
# ----------
# train Loss: 0.0394
# val   Loss: 0.0354
#
# Epoch 190/300
# ----------
# train Loss: 0.0377
# val   Loss: 0.0412
#
# Epoch 191/300
# ----------
# train Loss: 0.0369
# val   Loss: 0.0333
#
# Epoch 192/300
# ----------
# train Loss: 0.0348
# val   Loss: 0.0355
#
# Epoch 193/300
# ----------
# train Loss: 0.0354
# val   Loss: 0.0360
#
# Epoch 194/300
# ----------
# train Loss: 0.0316
# val   Loss: 0.0324
#
# Epoch 195/300
# ----------
# train Loss: 0.0346
# val   Loss: 0.0317
#
# Epoch 196/300
# ----------
# train Loss: 0.0320
# val   Loss: 0.0358
#
# Epoch 197/300
# ----------
# train Loss: 0.0342
# val   Loss: 0.0382
#
# Epoch 198/300
# ----------
# train Loss: 0.0465
# val   Loss: 0.0449
#
# Epoch 199/300
# ----------
# train Loss: 0.0440
# val   Loss: 0.0453
#
# Epoch 200/300
# ----------
# train Loss: 0.0466
# val   Loss: 0.0472
#
# Epoch 201/300
# ----------
# train Loss: 0.0471
# val   Loss: 0.0440
#
# Epoch 202/300
# ----------
# train Loss: 0.0438
# val   Loss: 0.0492
#
# Epoch 203/300
# ----------
# train Loss: 0.0525
# val   Loss: 0.0439
#
# Epoch 204/300
# ----------
# train Loss: 0.0418
# val   Loss: 0.0464
#
# Epoch 205/300
# ----------
# train Loss: 0.0441
# val   Loss: 0.0348
#
# Epoch 206/300
# ----------
# train Loss: 0.0367
# val   Loss: 0.0384
#
# Epoch 207/300
# ----------
# train Loss: 0.0380
# val   Loss: 0.0376
#
# Epoch 208/300
# ----------
# train Loss: 0.0356
# val   Loss: 0.0367
#
# Epoch 209/300
# ----------
# train Loss: 0.0381
# val   Loss: 0.0436
#
# Epoch 210/300
# ----------
# train Loss: 0.0413
# val   Loss: 0.0714
#
# Epoch 211/300
# ----------
# train Loss: 0.0699
# val   Loss: 0.0530
#
# Epoch 212/300
# ----------
# train Loss: 0.0555
# val   Loss: 0.0505
#
# Epoch 213/300
# ----------
# train Loss: 0.0500
# val   Loss: 0.0494
#
# Epoch 214/300
# ----------
# train Loss: 0.0460
# val   Loss: 0.0440
#
# Epoch 215/300
# ----------
# train Loss: 0.0431
# val   Loss: 0.0388
#
# Epoch 216/300
# ----------
# train Loss: 0.0409
# val   Loss: 0.0347
#
# Epoch 217/300
# ----------
# train Loss: 0.0372
# val   Loss: 0.0386
#
# Epoch 218/300
# ----------
# train Loss: 0.0391
# val   Loss: 0.0385
#
# Epoch 219/300
# ----------
# train Loss: 0.0366
# val   Loss: 0.0370
#
# Epoch 220/300
# ----------
# train Loss: 0.0349
# val   Loss: 0.0319
#
# Epoch 221/300
# ----------
# train Loss: 0.0328
# val   Loss: 0.0376
#
# Epoch 222/300
# ----------
# train Loss: 0.0376
# val   Loss: 0.0349
#
# Epoch 223/300
# ----------
# train Loss: 0.0395
# val   Loss: 0.0353
#
# Epoch 224/300
# ----------
# train Loss: 0.0377
# val   Loss: 0.0578
#
# Epoch 225/300
# ----------
# train Loss: 0.0540
# val   Loss: 0.0478
#
# Epoch 226/300
# ----------
# train Loss: 0.0450
# val   Loss: 0.0356
#
# Epoch 227/300
# ----------
# train Loss: 0.0434
# val   Loss: 0.0541
#
# Epoch 228/300
# ----------
# train Loss: 0.0520
# val   Loss: 0.0463
#
# Epoch 229/300
# ----------
# train Loss: 0.0475
# val   Loss: 0.0472
#
# Epoch 230/300
# ----------
# train Loss: 0.0423
# val   Loss: 0.0434
#
# Epoch 231/300
# ----------
# train Loss: 0.0445
# val   Loss: 0.0387
#
# Epoch 232/300
# ----------
# train Loss: 0.0379
# val   Loss: 0.0409
#
# Epoch 233/300
# ----------
# train Loss: 0.0407
# val   Loss: 0.0384
#
# Epoch 234/300
# ----------
# train Loss: 0.0372
# val   Loss: 0.0336
#
# Epoch 235/300
# ----------
# train Loss: 0.0348
# val   Loss: 0.0337
#
# Epoch 236/300
# ----------
# train Loss: 0.0359
# val   Loss: 0.0359
#
# Epoch 237/300
# ----------
# train Loss: 0.0364
# val   Loss: 0.0340
#
# Epoch 238/300
# ----------
# train Loss: 0.0370
# val   Loss: 0.0342
#
# Epoch 239/300
# ----------
# train Loss: 0.0378
# val   Loss: 0.0375
#
# Epoch 240/300
# ----------
# train Loss: 0.0389
# val   Loss: 0.0425
#
# Epoch 241/300
# ----------
# train Loss: 0.0452
# val   Loss: 0.0644
#
# Epoch 242/300
# ----------
# train Loss: 0.0580
# val   Loss: 0.0872
#
# Epoch 243/300
# ----------
# train Loss: 0.0704
# val   Loss: 0.0751
#
# Epoch 244/300
# ----------
# train Loss: 0.0625
# val   Loss: 0.0527
#
# Epoch 245/300
# ----------
# train Loss: 0.0496
# val   Loss: 0.0527
#
# Epoch 246/300
# ----------
# train Loss: 0.0467
# val   Loss: 0.0448
#
# Epoch 247/300
# ----------
# train Loss: 0.0441
# val   Loss: 0.0452
#
# Epoch 248/300
# ----------
# train Loss: 0.0452
# val   Loss: 0.0432
#
# Epoch 249/300
# ----------
# train Loss: 0.0407
# val   Loss: 0.0329
#
# Epoch 250/300
# ----------
# train Loss: 0.0382
# val   Loss: 0.0388
#
# Epoch 251/300
# ----------
# train Loss: 0.0351
# val   Loss: 0.0351
#
# Epoch 252/300
# ----------
# train Loss: 0.0349
# val   Loss: 0.0354
#
# Epoch 253/300
# ----------
# train Loss: 0.0360
# val   Loss: 0.0438
#
# Epoch 254/300
# ----------
# train Loss: 0.0371
# val   Loss: 0.0404
#
# Epoch 255/300
# ----------
# train Loss: 0.0408
# val   Loss: 0.0341
#
# Epoch 256/300
# ----------
# train Loss: 0.0352
# val   Loss: 0.0362
#
# Epoch 257/300
# ----------
# train Loss: 0.0450
# val   Loss: 0.0565
#
# Epoch 258/300
# ----------
# train Loss: 0.0499
# val   Loss: 0.0518
#
# Epoch 259/300
# ----------
# train Loss: 0.0521
# val   Loss: 0.0468
#
# Epoch 260/300
# ----------
# train Loss: 0.0446
# val   Loss: 0.0430
#
# Epoch 261/300
# ----------
# train Loss: 0.0419
# val   Loss: 0.0364
#
# Epoch 262/300
# ----------
# train Loss: 0.0419
# val   Loss: 0.0397
#
# Epoch 263/300
# ----------
# train Loss: 0.0433
# val   Loss: 0.0407
#
# Epoch 264/300
# ----------
# train Loss: 0.0408
# val   Loss: 0.0481
#
# Epoch 265/300
# ----------
# train Loss: 0.0451
# val   Loss: 0.0433
#
# Epoch 266/300
# ----------
# train Loss: 0.0445
# val   Loss: 0.0384
#
# Epoch 267/300
# ----------
# train Loss: 0.0434
# val   Loss: 0.0380
#
# Epoch 268/300
# ----------
# train Loss: 0.0380
# val   Loss: 0.0369
#
# Epoch 269/300
# ----------
# train Loss: 0.0370
# val   Loss: 0.0360
#
# Epoch 270/300
# ----------
# train Loss: 0.0386
# val   Loss: 0.0379
#
# Epoch 271/300
# ----------
# train Loss: 0.0559
# val   Loss: 0.0582
#
# Epoch 272/300
# ----------
# train Loss: 0.0607
# val   Loss: 0.0525
#
# Epoch 273/300
# ----------
# train Loss: 0.0506
# val   Loss: 0.0500
#
# Epoch 274/300
# ----------
# train Loss: 0.0477
# val   Loss: 0.0527
#
# Epoch 275/300
# ----------
# train Loss: 0.0497
# val   Loss: 0.0585
#
# Epoch 276/300
# ----------
# train Loss: 0.0530
# val   Loss: 0.0431
#
# Epoch 277/300
# ----------
# train Loss: 0.0453
# val   Loss: 0.0410
#
# Epoch 278/300
# ----------
# train Loss: 0.0388
# val   Loss: 0.0399
#
# Epoch 279/300
# ----------
# train Loss: 0.0377
# val   Loss: 0.0374
#
# Epoch 280/300
# ----------
# train Loss: 0.0381
# val   Loss: 0.0400
#
# Epoch 281/300
# ----------
# train Loss: 0.0421
# val   Loss: 0.0483
#
# Epoch 282/300
# ----------
# train Loss: 0.0478
# val   Loss: 0.0469
#
# Epoch 283/300
# ----------
# train Loss: 0.0437
# val   Loss: 0.0463
#
# Epoch 284/300
# ----------
# train Loss: 0.0475
# val   Loss: 0.0497
#
# Epoch 285/300
# ----------
# train Loss: 0.0475
# val   Loss: 0.0414
#
# Epoch 286/300
# ----------
# train Loss: 0.0458
# val   Loss: 0.0410
#
# Epoch 287/300
# ----------
# train Loss: 0.0427
# val   Loss: 0.0380
#
# Epoch 288/300
# ----------
# train Loss: 0.0426
# val   Loss: 0.0432
#
# Epoch 289/300
# ----------
# train Loss: 0.0391
# val   Loss: 0.0388
#
# Epoch 290/300
# ----------
# train Loss: 0.0362
# val   Loss: 0.0388
#
# Epoch 291/300
# ----------
# train Loss: 0.0413
# val   Loss: 0.0471
#
# Epoch 292/300
# ----------
# train Loss: 0.0497
# val   Loss: 0.0692
#
# Epoch 293/300
# ----------
# train Loss: 0.0609
# val   Loss: 0.0518
#
# Epoch 294/300
# ----------
# train Loss: 0.0612
# val   Loss: 0.0735
#
# Epoch 295/300
# ----------
# train Loss: 0.0619
# val   Loss: 0.0528
#
# Epoch 296/300
# ----------
# train Loss: 0.0558
# val   Loss: 0.0640
#
# Epoch 297/300
# ----------
# train Loss: 0.0572
# val   Loss: 0.0524
#
# Epoch 298/300
# ----------
# train Loss: 0.0491
# val   Loss: 0.0485
#
# Epoch 299/300
# ----------
# train Loss: 0.0457
# val   Loss: 0.0411
#
# Epoch 300/300
# ----------
# train Loss: 0.0415
# val   Loss: 0.0424
#
# Training complete in 1m 42s
# Best val Loss: 0.029846 at epoch 138
# (VAETrainingModel(
#    (encoder): Encoder(
#      (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (pool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#      (flatten): Flatten(start_dim=1, end_dim=-1)
#      (norm1): LayerNorm((274176,), eps=1e-05, elementwise_affine=True)
#      (relu): LeakyReLU(negative_slope=0.2)
#      (linear): Linear(in_features=274176, out_features=256, bias=True)
#      (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#      (mean): Linear(in_features=256, out_features=128, bias=True)
#      (var): Linear(in_features=256, out_features=128, bias=True)
#    )
#    (decoder): Decoder(
#      (latent_in): Linear(in_features=128, out_features=256, bias=True)
#      (hidden_layer): Linear(in_features=256, out_features=274176, bias=True)
#      (unflatten): Unflatten(dim=1, unflattened_size=(256, 119, 9))
#      (unpool): Upsample(
#        (refine_conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#      )
#      (unconv2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#      (unconv1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#      (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#      (norm2): LayerNorm((274176,), eps=1e-05, elementwise_affine=True)
#      (relu): LeakyReLU(negative_slope=0.2)
#      (sigmoid): Sigmoid()
#    )
#  ),
#  {'train_loss': [658.8431243896484,
#    140.18869590759277,
#    57.64451217651367,
#    75.42178916931152,
#    52.354926109313965,
#    26.1923189163208,
#    17.287813663482666,
#    15.574345588684082,
#    12.980597019195557,
#    8.330365419387817,
#    5.200192809104919,
#    4.718777656555176,
#    3.8679161071777344,
#    2.4121204018592834,
#    1.7734517455101013,
#    1.482020378112793,
#    1.1345332264900208,
#    0.782867819070816,
#    0.5993062406778336,
#    0.5003659427165985,
#    0.37625933438539505,
#    0.283384807407856,
#    0.2542121708393097,
#    0.1786709576845169,
#    0.15682031214237213,
#    0.13292618095874786,
#    0.05406663380563259,
#    0.046322436071932316,
#    0.04717498179525137,
#    0.043446469120681286,
#    0.03870843164622784,
#    0.0409160228446126,
#    0.0383518747985363,
#    0.03360089287161827,
#    0.03373775631189346,
#    0.03593100421130657,
#    0.03404153697192669,
#    0.034192733466625214,
#    0.03748142905533314,
#    0.04250961355865002,
#    0.06442300789058208,
#    0.08724856935441494,
#    0.07512276619672775,
#    0.052653055638074875,
#    0.05267566442489624,
#    0.044837397523224354,
#    0.04516647569835186,
#    0.043232993222773075,
#    0.03291785065084696,
#    0.03875871188938618,
#    0.035066611133515835,
#    0.03538367431610823,
#    0.043785485439002514,
#    0.0403679059818387,
#    0.034093000926077366,
#    0.03615383990108967,
#    0.05646822974085808,
#    0.05175158008933067,
#    0.04678294248878956,
#    0.043021174147725105,
#    0.03638478368520737,
#    0.03970846347510815,
#    0.04074817057698965,
#    0.04809692595154047,
#    0.043322778306901455,
#    0.038430933840572834,
#    0.03796830214560032,
#    0.036915820091962814,
#    0.036006007343530655,
#    0.03793619107455015,
#    0.05822381190955639,
#    0.05251878872513771,
#    0.04998015612363815,
#    0.05272260680794716,
#    0.05851798132061958,
#    0.04305494576692581,
#    0.041014598682522774,
#    0.03986993618309498,
#    0.037402939051389694,
#    0.04001011420041323,
#    0.048332441598176956,
#    0.046917375177145004,
#    0.046252998523414135,
#    0.04972396604716778,
#    0.04144965298473835,
#    0.041045007295906544,
#    0.03799045272171497,
#    0.0431614238768816,
#    0.03882021922618151,
#    0.03882684838026762,
#    0.04705962259322405,
#    0.06920828856527805,
#    0.051841432228684425,
#    0.07348468899726868,
#    0.05278243497014046,
#    0.06397582218050957,
#    0.05239841341972351,
#    0.04853658564388752,
#    0.04105878993868828,
#    0.04242193326354027]})

# %%
import math
# sample images from the latent space
import matplotlib.pyplot as plt
from matplotlib import gridspec

def stitch_and_show_images(x):
    """
    Stitch image slices horizontally and show the resulting single image.

    :param x: Tensor containing the image slices.
    :param slice_shape: Shape of each slice (channels, height, width).
    """
    x = x.view(-1, *slice_shape)  # Reshape
    x = x.permute(0, 2, 3, 1)     # Reorder dimensions for plotting

    # Concatenate all slices horizontally
    stitched_image = torch.cat(tuple(x), dim=1)
    
    # Calculate the full size for displaying
    full_width = stitched_image.shape[1]
    full_height = stitched_image.shape[0]
    dpi = 80  # Adjust dpi to your screen for accurate sizing (default is usually 80 or 100)
    figsize = full_width / dpi, full_height / dpi
    
    # Convert to numpy and plot
    fig = plt.figure(figsize=figsize, dpi=dpi)
    plt.imshow(stitched_image.cpu().numpy())
    plt.axis('off')
    plt.show()

# %%
for _ in range(2):
    with torch.no_grad():
        noise = torch.randn(SLICES, latent_size).to(DEVICE)
        generated_images = training_model.decoder(noise)
        stitch_and_show_images(generated_images)

# %%
with torch.no_grad():
    noise = torch.randn(SLICES, latent_size).to(DEVICE)
    trace = torch.jit.trace(training_model.decoder, noise)
    torch.jit.save(trace, 'out/model_conv_shallow.pt')
