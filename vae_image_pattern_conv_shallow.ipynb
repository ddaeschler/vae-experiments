# %%
from PIL import Image
from pillow_heif import register_heif_opener
import torch
import torch.nn.functional as F
import torch.nn as nn
import numpy as np
import torchvision.transforms as transforms
import time
import random

register_heif_opener()

image = Image.open('data/IMG_1432.HEIC')

print(image.size)
print(image.mode)
# Out:
# (1018, 240)
# RGB

# %%
DEVICE = 'mps'

transform = transforms.Compose([ 
    transforms.PILToTensor() 
])

img_tensor = transform(image)
img_tensor = img_tensor.to(torch.float) / 255.0

# clip the bottom and right 1-pixel edge as it contains random grey pixels (compression artifact?)
img_tensor = img_tensor[:, :, :-1]

print(img_tensor.shape)
# Out:
# torch.Size([3, 240, 1017])

# %%
IMAGE_CHANNELS = 3
SLICES = 50

# calculate slice width
slice_width = img_tensor.shape[2] // SLICES
slice_height = img_tensor.shape[1]
slice_shape = (IMAGE_CHANNELS, slice_height, slice_width)
# note that we are no longer flattening the slices because our 2D inputs will go
# to a conv layer

hidden_size = 256
latent_size = 128
conv_1_out = 64
conv_2_out = 128
conv_3_out = 256

slice_hw_ratio = slice_height//slice_width

print(f'Slice Shape: {slice_shape}')
print(f'Slice H/W Ratio: {slice_hw_ratio}')
# Out:
# Slice Shape: (3, 240, 20)
# Slice H/W Ratio: 12

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

def visualize_feature_maps(layer_output, num_feature_maps=10, cols=5):
    """
    Visualizes feature maps from a given layer output.

    Args:
    - layer_output (torch.Tensor): The output tensor from the layer you wish to visualize.
                                   Shape should be [N, C, H, W] (batch size, number of channels, height, width).
    - num_feature_maps (int): Number of feature maps to visualize. Default is 10.
    - cols (int): Number of columns in the subplot grid. Default is 5.
    """
    # Ensure layer_output is on CPU and detached from the computation graph
    feature_maps = layer_output[0].detach().cpu()

    # Determine the number of rows needed in the subplot grid
    rows = num_feature_maps // cols + int(num_feature_maps % cols != 0)

    # Set up the figure size and grid for plots
    fig, axes = plt.subplots(rows, cols, figsize=(cols, rows * 2.5))
    axes = axes.flatten()  # Flatten the axes array for easy iteration

    # Iterate and plot each feature map
    for i in range(num_feature_maps):
        if i < feature_maps.shape[0]:  # Check if the index is within the number of available feature maps
            # Access the feature map for the ith filter and convert to numpy
            feature_map = feature_maps[i].numpy()
            axes[i].imshow(feature_map, cmap='gray', aspect='auto')
            axes[i].axis('off')
            # axes[i].set_title(f'Feature Map {i+1}')
        else:
            axes[i].axis('off')  # Turn off axis for any unused subplot

    plt.tight_layout()
    plt.show()

# %%
# encoder portion. will take our slices and (learn to) encode them into the latent space
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        
        kernel_width = 3
        kernel_height = kernel_width * slice_hw_ratio
        
        self.conv1 = nn.Conv2d(in_channels=IMAGE_CHANNELS, out_channels=conv_1_out, kernel_size=3, 
                               stride=1, padding=1, padding_mode='zeros') # (conv_1_out, 1917, 81)
        self.conv2 = nn.Conv2d(in_channels=conv_1_out, out_channels=conv_2_out, kernel_size=3, 
                               stride=1, padding=1, padding_mode='zeros') # (conv_2_out, 1917, 81)
        self.conv3 = nn.Conv2d(in_channels=conv_2_out, out_channels=conv_3_out, kernel_size=3, 
                               stride=1, padding=1, padding_mode='zeros') # (conv_3_out, 1917, 81)
        self.pool1 = nn.MaxPool2d(kernel_size=3, stride=2) # (conv_3_out, 1917, 81)
        self.flatten = nn.Flatten() # (conv_3_out*957*39)
        self.norm1 = nn.LayerNorm([conv_3_out*119*9])
        self.relu = nn.LeakyReLU(0.2)
        self.linear = nn.Linear(conv_3_out*119*9, hidden_size)
        self.norm2 = nn.LayerNorm([hidden_size])
        self.mean = nn.Linear(hidden_size, latent_size)
        self.var = nn.Linear(hidden_size, latent_size)
        
    def forward(self, x):
        x = self.relu(self.conv1(x))
        #print(f'conv1 out shape: {x.shape}')
        x = self.relu(self.conv2(x))
        #print(f'conv2 out shape: {x.shape}')
        x = self.relu(self.conv3(x))
        #print(f'conv3 out shape: {x.shape}')
        x = self.pool1(x)
        #print(f'pool1 out shape: {x.shape}')
        x = self.flatten(x)
        x = self.relu(self.norm1(x))
        x = self.relu(self.norm2(self.linear(x)))
        
        mean = self.mean(x)
        log_variance = self.var(x)
        
        return mean, log_variance

class Upsample(nn.Module):
    def __init__(self, scale_factor, in_channels, out_channels, kernel_size, stride, padding, mode='nearest'):
        super(Upsample, self).__init__()
        self.scale_factor = scale_factor
        self.refine_conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.mode = mode

    def forward(self, x):
        x_upsampled = F.interpolate(x, scale_factor=self.scale_factor, mode=self.mode,
                                    align_corners=True if self.mode == 'bilinear' else None)
        return self.refine_conv(x_upsampled)

# decoder portion. takes data that is normally distributed in the latent space
# and decodes to the input space
class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        
        self.latent_in = nn.Linear(latent_size, hidden_size)
        self.hidden_layer = nn.Linear(hidden_size, conv_3_out*119*9)
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(conv_3_out,119,9))
        self.unpool = Upsample(mode='nearest', scale_factor=2, in_channels=conv_3_out, out_channels=conv_2_out,
                               kernel_size=3, stride=1, padding=2)
        self.unconv2 = nn.Conv2d(in_channels=conv_2_out, out_channels=conv_1_out, kernel_size=3, 
                               stride=1, padding=1, padding_mode='reflect')
        self.unconv1 = nn.Conv2d(in_channels=conv_1_out, out_channels=IMAGE_CHANNELS, kernel_size=3, 
                               stride=1, padding=1, padding_mode='reflect')
        
        self.norm1 = nn.LayerNorm([hidden_size])
        self.norm2 = nn.LayerNorm([conv_3_out*119*9])
        
        self.relu = nn.LeakyReLU(0.2)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        x = self.relu(self.norm1(self.latent_in(x)))
        x = self.relu(self.norm2(self.hidden_layer(x)))
        x = self.relu(self.unflatten(x))
        x = self.unpool(x)
        #visualize_feature_maps(x)
        #visualize_feature_maps(x)
        #print(f'uc3 shape: {x.shape}')
        x = self.unconv2(x)
        #print(f'uc2 shape: {x.shape}')
        x = self.unconv1(x)
        #print(f'uc1 shape: {x.shape}')
        x = self.sigmoid(x)
        
        return x
    
# puts it all together and adds the reparameterization trick to 
# establish the Gaussian distribution
class VAETrainingModel(nn.Module):
    def __init__(self, encoder, decoder):
        super(VAETrainingModel, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
    
    def reparameterize(self, mean, var):
        epsilon = torch.randn_like(var).to(DEVICE)
        return mean + epsilon * var
        
    def forward(self, x):
        mean, log_var = self.encoder(x)
        x = self.reparameterize(mean, log_var)
        x = self.decoder(x)
        
        return x, mean, log_var
    
def cost_function(x, x_pred, mean, log_var):
    #print(x.shape)
    #print(x_pred.shape)
    reproduction_loss = nn.functional.mse_loss(x_pred, x)
    KLD      = - 0.5 * torch.sum(1 + log_var - mean.pow(2) - log_var.exp())

    return reproduction_loss + KLD

# %%
BATCH_SIZE = 15
EPOCH_ITERS = img_tensor.shape[2] // slice_width // BATCH_SIZE
MODEL_WEIGHTS_FILE = 'out/model_conv.pt'

# train the model on the flattened data
def train_model(model, next_batch, criterion, optimizer, scheduler, num_epochs=25):
    print(f'Model is training with {num_epochs} epochs with {EPOCH_ITERS} iterations per epoch')
    since = time.time()

    best_loss = np.inf
    best_epoch = 0

    phases = ['train', 'val']

    # Keep track of how loss evolves during training
    training_curves = {}
    for phase in phases:
        training_curves[phase+'_loss'] = []

    for epoch in range(num_epochs):
        print(f'\nEpoch {epoch+1}/{num_epochs}')
        print('-' * 10)

        for phase in phases:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0

            # iterate over enough batches to try to cover the entire image (1 epoch)
            for _ in range(EPOCH_ITERS):
                inputs = next_batch(BATCH_SIZE)
                # print('Batch is', inputs.shape[0])
                inputs = inputs.to(DEVICE)
                # our targets are the same as our inputs
                targets = inputs.to(DEVICE)
                # print(inputs.shape)
                # print(targets.shape)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                with torch.set_grad_enabled(phase == 'train'):
                    x_pred, mean, log_var = model(inputs)
                    # print(outputs.shape)
                    loss = criterion(targets, x_pred, mean, log_var)

                    # backward + update weights only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / BATCH_SIZE
            training_curves[phase+'_loss'].append(epoch_loss)

            print(f'{phase:5} Loss: {epoch_loss:.4f}')

            # save the model if it's the best loss
            if phase == 'val' and epoch_loss < best_loss:
              best_epoch = epoch
              best_loss = epoch_loss
              with open(MODEL_WEIGHTS_FILE, 'wb') as f:
                torch.save(model.state_dict(), f)

    time_elapsed = time.time() - since
    print(f'\nTraining complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Loss: {best_loss:4f} at epoch {best_epoch}')

    # load best model weights
    model.load_state_dict(torch.load(MODEL_WEIGHTS_FILE, map_location=DEVICE))

    return model, training_curves

# %%
LEARNING_RATE = 1e-3

encoder = Encoder().to(DEVICE)
print('Encoder: ', sum(p.numel() for p in encoder.parameters())/1e6, 'M parameters')
decoder = Decoder().to(DEVICE)
print('Decoder: ', sum(p.numel() for p in decoder.parameters())/1e6, 'M parameters')
training_model = VAETrainingModel(encoder, decoder).to(DEVICE)

optimizer_ = torch.optim.AdamW(training_model.parameters(), lr=LEARNING_RATE)
scheduler_ = torch.optim.lr_scheduler.ExponentialLR(optimizer_, gamma=0.98)
# Out:
# Encoder:  141.561472 M parameters
# Decoder:  141.703811 M parameters

# %%
def get_batch(batch_size):
    """ Returns a batch consisting of batch_size slices of the training data """
    # our img_tensor is torch.Size([3, 1917, 8141])
    # so we want to start at a random spot in the tensor that is < slice_width
    # then take a slice_width chunk of the 3rd dimension which is the width
    
    # calculate the maximum start index for the width
    max_start_index_width = img_tensor.size(2) - slice_width

    batch_list = []
    for _ in range(batch_size):
        start = random.randint(0, max_start_index_width)
        img_slice = img_tensor[:, :, start:start + slice_width]
        #print(f'Random tensor of size {img_slice.shape} width at {start} ')
        batch_list.append(img_slice)
        
    ret = torch.stack(batch_list)
    #print(ret.shape)
    return ret

# %%
EPOCHS = 200
train_model(training_model, get_batch, cost_function, optimizer_, scheduler_, EPOCHS)
# Out:
# Model is training with 200 epochs with 3 iterations per epoch
#
# Epoch 1/200
# ----------
# train Loss: 1234.7445
# val   Loss: 284.7369
#
# Epoch 2/200
# ----------
# train Loss: 234.6940
# val   Loss: 261.9742
#
# Epoch 3/200
# ----------
# train Loss: 248.6684
# val   Loss: 192.5539
#
# Epoch 4/200
# ----------
# train Loss: 158.6001
# val   Loss: 106.2638
#
# Epoch 5/200
# ----------
# train Loss: 92.8960
# val   Loss: 72.7790
#
# Epoch 6/200
# ----------
# train Loss: 67.6684
# val   Loss: 59.1547
#
# Epoch 7/200
# ----------
# train Loss: 53.7766
# val   Loss: 42.2672
#
# Epoch 8/200
# ----------
# train Loss: 38.3442
# val   Loss: 31.9736
#
# Epoch 9/200
# ----------
# train Loss: 28.3202
# val   Loss: 20.6291
#
# Epoch 10/200
# ----------
# train Loss: 18.3505
# val   Loss: 16.2207
#
# Epoch 11/200
# ----------
# train Loss: 15.7679
# val   Loss: 13.3123
#
# Epoch 12/200
# ----------
# train Loss: 11.2745
# val   Loss: 8.0433
#
# Epoch 13/200
# ----------
# train Loss: 7.4946
# val   Loss: 6.7782
#
# Epoch 14/200
# ----------
# train Loss: 6.2135
# val   Loss: 4.7819
#
# Epoch 15/200
# ----------
# train Loss: 4.1835
# val   Loss: 3.3803
#
# Epoch 16/200
# ----------
# train Loss: 3.1772
# val   Loss: 2.7394
#
# Epoch 17/200
# ----------
# train Loss: 2.4928
# val   Loss: 1.8608
#
# Epoch 18/200
# ----------
# train Loss: 1.5934
# val   Loss: 1.3113
#
# Epoch 19/200
# ----------
# train Loss: 1.3028
# val   Loss: 1.1603
#
# Epoch 20/200
# ----------
# train Loss: 0.9966
# val   Loss: 0.7117
#
# Epoch 21/200
# ----------
# train Loss: 0.6610
# val   Loss: 0.5874
#
# Epoch 22/200
# ----------
# train Loss: 0.5306
# val   Loss: 0.4422
#
# Epoch 23/200
# ----------
# train Loss: 0.3971
# val   Loss: 0.3220
#
# Epoch 24/200
# ----------
# train Loss: 0.2976
# val   Loss: 0.2578
#
# Epoch 25/200
# ----------
# train Loss: 0.2309
# val   Loss: 0.1901
#
# Epoch 26/200
# ----------
# train Loss: 0.1722
# val   Loss: 0.1580
#
# Epoch 27/200
# ----------
# train Loss: 0.1458
# val   Loss: 0.1201
#
# Epoch 28/200
# ----------
# train Loss: 0.1121
# val   Loss: 0.1021
#
# Epoch 29/200
# ----------
# train Loss: 0.0948
# val   Loss: 0.0769
#
# Epoch 30/200
# ----------
# train Loss: 0.0831
# val   Loss: 0.0735
#
# Epoch 31/200
# ----------
# train Loss: 0.0723
# val   Loss: 0.0609
#
# Epoch 32/200
# ----------
# train Loss: 0.0662
# val   Loss: 0.0586
#
# Epoch 33/200
# ----------
# train Loss: 0.0552
# val   Loss: 0.0511
#
# Epoch 34/200
# ----------
# train Loss: 0.0527
# val   Loss: 0.0469
#
# Epoch 35/200
# ----------
# train Loss: 0.0479
# val   Loss: 0.0510
#
# Epoch 36/200
# ----------
# train Loss: 0.0484
# val   Loss: 0.0482
#
# Epoch 37/200
# ----------
# train Loss: 0.0427
# val   Loss: 0.0479
#
# Epoch 38/200
# ----------
# train Loss: 0.0431
# val   Loss: 0.0427
#
# Epoch 39/200
# ----------
# train Loss: 0.0396
# val   Loss: 0.0396
#
# Epoch 40/200
# ----------
# train Loss: 0.0429
# val   Loss: 0.0424
#
# Epoch 41/200
# ----------
# train Loss: 0.0414
# val   Loss: 0.0386
#
# Epoch 42/200
# ----------
# train Loss: 0.0422
# val   Loss: 0.0386
#
# Epoch 43/200
# ----------
# train Loss: 0.0437
# val   Loss: 0.0393
#
# Epoch 44/200
# ----------
# train Loss: 0.0429
# val   Loss: 0.0404
#
# Epoch 45/200
# ----------
# train Loss: 0.0411
# val   Loss: 0.0419
#
# Epoch 46/200
# ----------
# train Loss: 0.0426
# val   Loss: 0.0457
#
# Epoch 47/200
# ----------
# train Loss: 0.0420
# val   Loss: 0.0423
#
# Epoch 48/200
# ----------
# train Loss: 0.0398
# val   Loss: 0.0396
#
# Epoch 49/200
# ----------
# train Loss: 0.0425
# val   Loss: 0.0404
#
# Epoch 50/200
# ----------
# train Loss: 0.0380
# val   Loss: 0.0390
#
# Epoch 51/200
# ----------
# train Loss: 0.0419
# val   Loss: 0.0453
#
# Epoch 52/200
# ----------
# train Loss: 0.0377
# val   Loss: 0.0422
#
# Epoch 53/200
# ----------
# train Loss: 0.0382
# val   Loss: 0.0382
#
# Epoch 54/200
# ----------
# train Loss: 0.0441
# val   Loss: 0.0383
#
# Epoch 55/200
# ----------
# train Loss: 0.0396
# val   Loss: 0.0434
#
# Epoch 56/200
# ----------
# train Loss: 0.0390
# val   Loss: 0.0407
#
# Epoch 57/200
# ----------
# train Loss: 0.0373
# val   Loss: 0.0385
#
# Epoch 58/200
# ----------
# train Loss: 0.0370
# val   Loss: 0.0426
#
# Epoch 59/200
# ----------
# train Loss: 0.0419
# val   Loss: 0.0367
#
# Epoch 60/200
# ----------
# train Loss: 0.0382
# val   Loss: 0.0368
#
# Epoch 61/200
# ----------
# train Loss: 0.0416
# val   Loss: 0.0386
#
# Epoch 62/200
# ----------
# train Loss: 0.0403
# val   Loss: 0.0401
#
# Epoch 63/200
# ----------
# train Loss: 0.0412
# val   Loss: 0.0422
#
# Epoch 64/200
# ----------
# train Loss: 0.0380
# val   Loss: 0.0376
#
# Epoch 65/200
# ----------
# train Loss: 0.0365
# val   Loss: 0.0419
#
# Epoch 66/200
# ----------
# train Loss: 0.0388
# val   Loss: 0.0406
#
# Epoch 67/200
# ----------
# train Loss: 0.0418
# val   Loss: 0.0441
#
# Epoch 68/200
# ----------
# train Loss: 0.0477
# val   Loss: 0.0352
#
# Epoch 69/200
# ----------
# train Loss: 0.0430
# val   Loss: 0.0393
#
# Epoch 70/200
# ----------
# train Loss: 0.0372
# val   Loss: 0.0415
#
# Epoch 71/200
# ----------
# train Loss: 0.0369
# val   Loss: 0.0410
#
# Epoch 72/200
# ----------
# train Loss: 0.0392
# val   Loss: 0.0407
#
# Epoch 73/200
# ----------
# train Loss: 0.0437
# val   Loss: 0.0378
#
# Epoch 74/200
# ----------
# train Loss: 0.0472
# val   Loss: 0.0386
#
# Epoch 75/200
# ----------
# train Loss: 0.0395
# val   Loss: 0.0377
#
# Epoch 76/200
# ----------
# train Loss: 0.0432
# val   Loss: 0.0416
#
# Epoch 77/200
# ----------
# train Loss: 0.0404
# val   Loss: 0.0408
#
# Epoch 78/200
# ----------
# train Loss: 0.0375
# val   Loss: 0.0349
#
# Epoch 79/200
# ----------
# train Loss: 0.0373
# val   Loss: 0.0404
#
# Epoch 80/200
# ----------
# train Loss: 0.0462
# val   Loss: 0.0394
#
# Epoch 81/200
# ----------
# train Loss: 0.0390
# val   Loss: 0.0394
#
# Epoch 82/200
# ----------
# train Loss: 0.0392
# val   Loss: 0.0389
#
# Epoch 83/200
# ----------
# train Loss: 0.0394
# val   Loss: 0.0404
#
# Epoch 84/200
# ----------
# train Loss: 0.0392
# val   Loss: 0.0365
#
# Epoch 85/200
# ----------
# train Loss: 0.0404
# val   Loss: 0.0433
#
# Epoch 86/200
# ----------
# train Loss: 0.0407
# val   Loss: 0.0416
#
# Epoch 87/200
# ----------
# train Loss: 0.0433
# val   Loss: 0.0455
#
# Epoch 88/200
# ----------
# train Loss: 0.0419
# val   Loss: 0.0325
#
# Epoch 89/200
# ----------
# train Loss: 0.0343
# val   Loss: 0.0378
#
# Epoch 90/200
# ----------
# train Loss: 0.0397
# val   Loss: 0.0362
#
# Epoch 91/200
# ----------
# train Loss: 0.0434
# val   Loss: 0.0391
#
# Epoch 92/200
# ----------
# train Loss: 0.0339
# val   Loss: 0.0404
#
# Epoch 93/200
# ----------
# train Loss: 0.0334
# val   Loss: 0.0384
#
# Epoch 94/200
# ----------
# train Loss: 0.0358
# val   Loss: 0.0367
#
# Epoch 95/200
# ----------
# train Loss: 0.0414
# val   Loss: 0.0357
#
# Epoch 96/200
# ----------
# train Loss: 0.0365
# val   Loss: 0.0435
#
# Epoch 97/200
# ----------
# train Loss: 0.0380
# val   Loss: 0.0398
#
# Epoch 98/200
# ----------
# train Loss: 0.0322
# val   Loss: 0.0414
#
# Epoch 99/200
# ----------
# train Loss: 0.0364
# val   Loss: 0.0362
#
# Epoch 100/200
# ----------
# train Loss: 0.0374
# val   Loss: 0.0437
#
# Epoch 101/200
# ----------
# train Loss: 0.0364
# val   Loss: 0.0411
#
# Epoch 102/200
# ----------
# train Loss: 0.0453
# val   Loss: 0.0398
#
# Epoch 103/200
# ----------
# train Loss: 0.0372
# val   Loss: 0.0370
#
# Epoch 104/200
# ----------
# train Loss: 0.0412
# val   Loss: 0.0367
#
# Epoch 105/200
# ----------
# train Loss: 0.0405
# val   Loss: 0.0352
#
# Epoch 106/200
# ----------
# train Loss: 0.0332
# val   Loss: 0.0329
#
# Epoch 107/200
# ----------
# train Loss: 0.0365
# val   Loss: 0.0419
#
# Epoch 108/200
# ----------
# train Loss: 0.0402
# val   Loss: 0.0393
#
# Epoch 109/200
# ----------
# train Loss: 0.0388
# val   Loss: 0.0367
#
# Epoch 110/200
# ----------
# train Loss: 0.0384
# val   Loss: 0.0368
#
# Epoch 111/200
# ----------
# train Loss: 0.0391
# val   Loss: 0.0394
#
# Epoch 112/200
# ----------
# train Loss: 0.0383
# val   Loss: 0.0410
#
# Epoch 113/200
# ----------
# train Loss: 0.0397
# val   Loss: 0.0398
#
# Epoch 114/200
# ----------
# train Loss: 0.0417
# val   Loss: 0.0397
#
# Epoch 115/200
# ----------
# train Loss: 0.0393
# val   Loss: 0.0380
#
# Epoch 116/200
# ----------
# train Loss: 0.0370
# val   Loss: 0.0383
#
# Epoch 117/200
# ----------
# train Loss: 0.0378
# val   Loss: 0.0352
#
# Epoch 118/200
# ----------
# train Loss: 0.0390
# val   Loss: 0.0368
#
# Epoch 119/200
# ----------
# train Loss: 0.0366
# val   Loss: 0.0394
#
# Epoch 120/200
# ----------
# train Loss: 0.0360
# val   Loss: 0.0375
#
# Epoch 121/200
# ----------
# train Loss: 0.0395
# val   Loss: 0.0384
#
# Epoch 122/200
# ----------
# train Loss: 0.0361
# val   Loss: 0.0355
#
# Epoch 123/200
# ----------
# train Loss: 0.0411
# val   Loss: 0.0397
#
# Epoch 124/200
# ----------
# train Loss: 0.0354
# val   Loss: 0.0376
#
# Epoch 125/200
# ----------
# train Loss: 0.0355
# val   Loss: 0.0379
#
# Epoch 126/200
# ----------
# train Loss: 0.0397
# val   Loss: 0.0352
#
# Epoch 127/200
# ----------
# train Loss: 0.0358
# val   Loss: 0.0369
#
# Epoch 128/200
# ----------
# train Loss: 0.0411
# val   Loss: 0.0343
#
# Epoch 129/200
# ----------
# train Loss: 0.0379
# val   Loss: 0.0392
#
# Epoch 130/200
# ----------
# train Loss: 0.0387
# val   Loss: 0.0390
#
# Epoch 131/200
# ----------
# train Loss: 0.0327
# val   Loss: 0.0406
#
# Epoch 132/200
# ----------
# train Loss: 0.0418
# val   Loss: 0.0368
#
# Epoch 133/200
# ----------
# train Loss: 0.0368
# val   Loss: 0.0367
#
# Epoch 134/200
# ----------
# train Loss: 0.0382
# val   Loss: 0.0416
#
# Epoch 135/200
# ----------
# train Loss: 0.0341
# val   Loss: 0.0346
#
# Epoch 136/200
# ----------
# train Loss: 0.0339
# val   Loss: 0.0398
#
# Epoch 137/200
# ----------
# train Loss: 0.0345
# val   Loss: 0.0367
#
# Epoch 138/200
# ----------
# train Loss: 0.0332
# val   Loss: 0.0366
#
# Epoch 139/200
# ----------
# train Loss: 0.0390
# val   Loss: 0.0357
#
# Epoch 140/200
# ----------
# train Loss: 0.0370
# val   Loss: 0.0395
#
# Epoch 141/200
# ----------
# train Loss: 0.0371
# val   Loss: 0.0383
#
# Epoch 142/200
# ----------
# train Loss: 0.0367
# val   Loss: 0.0384
#
# Epoch 143/200
# ----------
# train Loss: 0.0398
# val   Loss: 0.0361
#
# Epoch 144/200
# ----------
# train Loss: 0.0388
# val   Loss: 0.0370
#
# Epoch 145/200
# ----------
# train Loss: 0.0325
# val   Loss: 0.0364
#
# Epoch 146/200
# ----------
# train Loss: 0.0341
# val   Loss: 0.0315
#
# Epoch 147/200
# ----------
# train Loss: 0.0366
# val   Loss: 0.0324
#
# Epoch 148/200
# ----------
# train Loss: 0.0353
# val   Loss: 0.0340
#
# Epoch 149/200
# ----------
# train Loss: 0.0381
# val   Loss: 0.0339
#
# Epoch 150/200
# ----------
# train Loss: 0.0404
# val   Loss: 0.0333
#
# Epoch 151/200
# ----------
# train Loss: 0.0361
# val   Loss: 0.0351
#
# Epoch 152/200
# ----------
# train Loss: 0.0437
# val   Loss: 0.0357
#
# Epoch 153/200
# ----------
# train Loss: 0.0332
# val   Loss: 0.0417
#
# Epoch 154/200
# ----------
# train Loss: 0.0396
# val   Loss: 0.0368
#
# Epoch 155/200
# ----------
# train Loss: 0.0340
# val   Loss: 0.0382
#
# Epoch 156/200
# ----------
# train Loss: 0.0358
# val   Loss: 0.0341
#
# Epoch 157/200
# ----------
# train Loss: 0.0321
# val   Loss: 0.0359
#
# Epoch 158/200
# ----------
# train Loss: 0.0334
# val   Loss: 0.0420
#
# Epoch 159/200
# ----------
# train Loss: 0.0345
# val   Loss: 0.0371
#
# Epoch 160/200
# ----------
# train Loss: 0.0372
# val   Loss: 0.0349
#
# Epoch 161/200
# ----------
# train Loss: 0.0362
# val   Loss: 0.0351
#
# Epoch 162/200
# ----------
# train Loss: 0.0381
# val   Loss: 0.0377
#
# Epoch 163/200
# ----------
# train Loss: 0.0359
# val   Loss: 0.0387
#
# Epoch 164/200
# ----------
# train Loss: 0.0402
# val   Loss: 0.0352
#
# Epoch 165/200
# ----------
# train Loss: 0.0325
# val   Loss: 0.0361
#
# Epoch 166/200
# ----------
# train Loss: 0.0369
# val   Loss: 0.0392
#
# Epoch 167/200
# ----------
# train Loss: 0.0339
# val   Loss: 0.0369
#
# Epoch 168/200
# ----------
# train Loss: 0.0380
# val   Loss: 0.0375
#
# Epoch 169/200
# ----------
# train Loss: 0.0355
# val   Loss: 0.0329
#
# Epoch 170/200
# ----------
# train Loss: 0.0338
# val   Loss: 0.0359
#
# Epoch 171/200
# ----------
# train Loss: 0.0295
# val   Loss: 0.0317
#
# Epoch 172/200
# ----------
# train Loss: 0.0355
# val   Loss: 0.0367
#
# Epoch 173/200
# ----------
# train Loss: 0.0375
# val   Loss: 0.0305
#
# Epoch 174/200
# ----------
# train Loss: 0.0342
# val   Loss: 0.0336
#
# Epoch 175/200
# ----------
# train Loss: 0.0371
# val   Loss: 0.0351
#
# Epoch 176/200
# ----------
# train Loss: 0.0402
# val   Loss: 0.0374
#
# Epoch 177/200
# ----------
# train Loss: 0.0352
# val   Loss: 0.0372
#
# Epoch 178/200
# ----------
# train Loss: 0.0351
# val   Loss: 0.0382
#
# Epoch 179/200
# ----------
# train Loss: 0.0330
# val   Loss: 0.0320
#
# Epoch 180/200
# ----------
# train Loss: 0.0402
# val   Loss: 0.0350
#
# Epoch 181/200
# ----------
# train Loss: 0.0345
# val   Loss: 0.0338
#
# Epoch 182/200
# ----------
# train Loss: 0.0336
# val   Loss: 0.0376
#
# Epoch 183/200
# ----------
# train Loss: 0.0380
# val   Loss: 0.0387
#
# Epoch 184/200
# ----------
# train Loss: 0.0344
# val   Loss: 0.0382
#
# Epoch 185/200
# ----------
# train Loss: 0.0368
# val   Loss: 0.0344
#
# Epoch 186/200
# ----------
# train Loss: 0.0392
# val   Loss: 0.0366
#
# Epoch 187/200
# ----------
# train Loss: 0.0345
# val   Loss: 0.0358
#
# Epoch 188/200
# ----------
# train Loss: 0.0388
# val   Loss: 0.0334
#
# Epoch 189/200
# ----------
# train Loss: 0.0330
# val   Loss: 0.0329
#
# Epoch 190/200
# ----------
# train Loss: 0.0349
# val   Loss: 0.0335
#
# Epoch 191/200
# ----------
# train Loss: 0.0391
# val   Loss: 0.0362
#
# Epoch 192/200
# ----------
# train Loss: 0.0374
# val   Loss: 0.0365
#
# Epoch 193/200
# ----------
# train Loss: 0.0322
# val   Loss: 0.0395
#
# Epoch 194/200
# ----------
# train Loss: 0.0392
# val   Loss: 0.0344
#
# Epoch 195/200
# ----------
# train Loss: 0.0374
# val   Loss: 0.0341
#
# Epoch 196/200
# ----------
# train Loss: 0.0364
# val   Loss: 0.0343
#
# Epoch 197/200
# ----------
# train Loss: 0.0341
# val   Loss: 0.0356
#
# Epoch 198/200
# ----------
# train Loss: 0.0334
# val   Loss: 0.0380
#
# Epoch 199/200
# ----------
# train Loss: 0.0349
# val   Loss: 0.0378
#
# Epoch 200/200
# ----------
# train Loss: 0.0348
# val   Loss: 0.0369
#
# Training complete in 1m 50s
# Best val Loss: 0.030538 at epoch 172
# (VAETrainingModel(
#    (encoder): Encoder(
#      (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#      (pool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#      (flatten): Flatten(start_dim=1, end_dim=-1)
#      (norm1): LayerNorm((274176,), eps=1e-05, elementwise_affine=True)
#      (relu): LeakyReLU(negative_slope=0.2)
#      (linear): Linear(in_features=274176, out_features=512, bias=True)
#      (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#      (mean): Linear(in_features=512, out_features=256, bias=True)
#      (var): Linear(in_features=512, out_features=256, bias=True)
#    )
#    (decoder): Decoder(
#      (latent_in): Linear(in_features=256, out_features=512, bias=True)
#      (hidden_layer): Linear(in_features=512, out_features=274176, bias=True)
#      (unflatten): Unflatten(dim=1, unflattened_size=(256, 119, 9))
#      (unpool): Upsample(
#        (refine_conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#      )
#      (unconv2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#      (unconv1): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#      (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#      (norm2): LayerNorm((274176,), eps=1e-05, elementwise_affine=True)
#      (relu): LeakyReLU(negative_slope=0.2)
#      (sigmoid): Sigmoid()
#    )
#  ),
#  {'train_loss': [1234.7444610595703,
#    234.69400787353516,
#    248.6683807373047,
#    158.60005950927734,
#    92.89600372314453,
#    67.66841888427734,
#    53.776588439941406,
#    38.34422588348389,
#    28.32024574279785,
#    18.350525379180908,
#    15.76792860031128,
#    11.274500608444214,
#    7.494596242904663,
#    6.21346640586853,
#    4.183483004570007,
#    3.177203059196472,
#    2.492753267288208,
#    1.5934388935565948,
#    1.3028203845024109,
#    0.9965737462043762,
#    0.6609722524881363,
#    0.5305846482515335,
#    0.3970603719353676,
#    0.29758135229349136,
#    0.23091409355401993,
#    0.17221130430698395,
#    0.1458478532731533,
#    0.11212068796157837,
#    0.09478487074375153,
#    0.08308835700154305,
#    0.07233923487365246,
#    0.06620245426893234,
#    0.055158134549856186,
#    0.05268807243555784,
#    0.047861660830676556,
#    0.04843808896839619,
#    0.042666721157729626,
#    0.04313445184379816,
#    0.03962225839495659,
#    0.042871272191405296,
#    0.041434623301029205,
#    0.04220552369952202,
#    0.04371264576911926,
#    0.042884061112999916,
#    0.04112318530678749,
#    0.04257588181644678,
#    0.041953071020543575,
#    0.03976364620029926,
#    0.04249539505690336,
#    0.038047971203923225,
#    0.04190264921635389,
#    0.03774911072105169,
#    0.03819737769663334,
#    0.04410805832594633,
#    0.039610205218195915,
#    0.03902184031903744,
#    0.037323009222745895,
#    0.03700082469731569,
#    0.04192196112126112,
#    0.03815420623868704,
#    0.04162336140871048,
#    0.04033693205565214,
#    0.041191257536411285,
#    0.037992801517248154,
#    0.0365055650472641,
#    0.038831232115626335,
#    0.041818173602223396,
#    0.04772062227129936,
#    0.0430489107966423,
#    0.037242296151816845,
#    0.036903681233525276,
#    0.039208292961120605,
#    0.04367879591882229,
#    0.04722620639950037,
#    0.03949014749377966,
#    0.0431901291012764,
#    0.04036526661366224,
#    0.037495301105082035,
#    0.03727097436785698,
#    0.04620662610977888,
#    0.03902257140725851,
#    0.03916756808757782,
#    0.03939286805689335,
#    0.03923417069017887,
#    0.04037740174680948,
#    0.04074275679886341,
#    0.04328652750700712,
#    0.0418684221804142,
#    0.03431686107069254,
#    0.039656839333474636,
#    0.043427543714642525,
#    0.033917360939085484,
#    0.033396399579942226,
#    0.035798377357423306,
#    0.04135351628065109,
#    0.036478981375694275,
#    0.0379533963277936,
#    0.0321841798722744,
#    0.036397495307028294,
#    0.037362526170909405,
#    0.03643447533249855,
#    0.045316653326153755,
#    0.037239063531160355,
#    0.04123706743121147,
#    0.040531634353101254,
#    0.03320235759019852,
#    0.036525038070976734,
#    0.04021938797086477,
#    0.038824805058538914,
#    0.03840975742787123,
#    0.039121231995522976,
#    0.03830681648105383,
#    0.03971941024065018,
#    0.041737272404134274,
#    0.039271860383450985,
#    0.036997598595917225,
#    0.037807769142091274,
#    0.03899343032389879,
#    0.03663434274494648,
#    0.03598592709749937,
#    0.03953182511031628,
#    0.03609476611018181,
#    0.04105713777244091,
#    0.035409449599683285,
#    0.03554808348417282,
#    0.039674936793744564,
#    0.035822450183331966,
#    0.04106099344789982,
#    0.03793041128665209,
#    0.03866854216903448,
#    0.032735707238316536,
#    0.04183144960552454,
#    0.03676705248653889,
#    0.03818136174231768,
#    0.03409115690737963,
#    0.03390444163233042,
#    0.034500972367823124,
#    0.033157749101519585,
#    0.038989411666989326,
#    0.036976068280637264,
#    0.037062120623886585,
#    0.03667419031262398,
#    0.03984424751251936,
#    0.03876613825559616,
#    0.03253538720309734,
#    0.03405492287129164,
#    0.03657909482717514,
#    0.035266756080091,
#    0.03808834310621023,
#    0.04037078469991684,
#    0.03611100930720568,
#    0.04369197692722082,
#    0.03315343149006367,
#    0.03963824454694986,
#    0.03400216996669769,
#    0.035801807418465614,
#    0.03214976005256176,
#    0.033396958373486996,
#    0.03446926083415747,
#    0.03716282267123461,
#    0.03624679706990719,
#    0.03812398388981819,
#    0.03587740380316973,
#    0.04019028972834349,
#    0.032501175068318844,
#    0.03688898030668497,
#    0.033900526352226734,
#    0.03795648738741875,
#    0.03553721122443676,
#    0.033845625817775726,
#    0.029501047916710377,
#    0.03549132961779833,
#    0.03751186281442642,
#    0.03415447473526001,
#    0.03706228360533714,
#    0.040170757099986076,
#    0.03521283250302076,
#    0.03506076708436012,
#    0.0329735167324543,
#    0.04023860953748226,
#    0.03454434219747782,
#    0.03360698837786913,
#    0.03803804703056812,
#    0.0344280106946826,
#    0.0367705300450325,
#    0.0391817232593894,
#    0.0345321586355567,
#    0.038836888037621975,
#    0.03296919446438551,
#    0.03492886945605278,
#    0.03905602544546127,
#    0.03743048012256622,
#    0.0321970796212554,
#    0.03916594572365284,
#    0.037377238273620605,
#    0.036444918252527714,
#    0.03414696175605059,
#    0.03344856109470129,
#    0.0349047789350152,
#    0.03479723259806633],
#   'val_loss': [284.7369155883789,
#    261.9741973876953,
#    192.55388641357422,
#    106.26375579833984,
#    72.77898788452148,
#    59.15469551086426,
#    42.267245292663574,
#    31.973563194274902,
#    20.62906312942505,
#    16.220669746398926,
#    13.312309741973877,
#    8.043338298797607,
#    6.7782323360443115,
#    4.781862497329712,
#    3.3803277015686035,
#    2.739423394203186,
#    1.8608151078224182,
#    1.3113260865211487,
#    1.1603090167045593,
#    0.7116673141717911,
#    0.5873624384403229,
#    0.44221945106983185,
#    0.32196731120347977,
#    0.25780201703310013,
#    0.19014394283294678,
#    0.15795014798641205,
#    0.12014119327068329,
#    0.10212307423353195,
#    0.07687740959227085,
#    0.07349483482539654,
#    0.06089893355965614,
#    0.058644700795412064,
#    0.05105880834162235,
#    0.046866036020219326,
#    0.05101056024432182,
#    0.048170410096645355,
#    0.04786285385489464,
#    0.042725938372313976,
#    0.03963412530720234,
#    0.04235518258064985,
#    0.03855596575886011,
#    0.03855810407549143,
#    0.039279231801629066,
#    0.0403761463239789,
#    0.04192984290421009,
#    0.04568977188318968,
#    0.04228079505264759,
#    0.03955313004553318,
#    0.04038634430617094,
#    0.038994818925857544,
#    0.04526108410209417,
#    0.04215583670884371,
#    0.03818559553474188,
#    0.03827499784529209,
#    0.04339760448783636,
#    0.040695156902074814,
#    0.0385321956127882,
#    0.04263543616980314,
#    0.03673013858497143,
#    0.036753036081790924,
#    0.038575662299990654,
#    0.0400979733094573,
#    0.04217436257749796,
#    0.03764279559254646,
#    0.0419318787753582,
#    0.04055741988122463,
#    0.04413348715752363,
#    0.03523496724665165,
#    0.039326487109065056,
#    0.04150571767240763,
#    0.04100560210645199,
#    0.04071872495114803,
#    0.03779929690063,
#    0.038572268560528755,
#    0.037679669447243214,
#    0.04163996037095785,
#    0.04081022273749113,
#    0.034922352991998196,
#    0.04036520700901747,
#    0.039367396384477615,
#    0.03944963961839676,
#    0.03894554544240236,
#    0.04043860174715519,
#    0.03646397963166237,
#    0.04328563064336777,
#    0.04156816843897104,
#    0.04552513640373945,
#    0.03245515562593937,
#    0.03777598403394222,
#    0.03622344508767128,
#    0.03909615986049175,
#    0.04037168622016907,
#    0.03838449344038963,
#    0.036735846661031246,
#    0.03566671255975962,
#    0.04348777513951063,
#    0.03976073954254389,
#    0.04144259076565504,
#    0.03621991444379091,
#    0.04367018025368452,
#    0.04114038683474064,
#    0.03983943536877632,
#    0.03703540749847889,
#    0.0367104010656476,
#    0.03522177506238222,
#    0.032873732037842274,
#    0.04187321197241545,
#    0.03925654664635658,
#    0.036674290895462036,
#    0.036846473813056946,
#    0.03935377113521099,
#    0.040968380868434906,
#    0.039820387959480286,
#    0.03965057712048292,
#    0.038035946898162365,
#    0.03830213285982609,
#    0.03523425664752722,
#    0.036756377667188644,
#    0.039395724423229694,
#    0.037504817359149456,
#    0.03836329001933336,
#    0.035501391626894474,
#    0.03970534261316061,
#    0.03756922576576471,
#    0.03787436801940203,
#    0.03518604300916195,
#    0.03685146942734718,
#    0.03426018077880144,
#    0.03915057145059109,
#    0.03898347448557615,
#    0.04060282278805971,
#    0.036751242354512215,
#    0.03671145346015692,
#    0.04159379005432129,
#    0.03463377710431814,
#    0.03978235647082329,
#    0.036725327372550964,
#    0.03655631933361292,
#    0.03571936767548323,
#    0.039533681236207485,
#    0.038305879570543766,
#    0.03843885753303766,
#    0.03610469680279493,
#    0.03702382743358612,
#    0.03640213143080473,
#    0.03154935594648123,
#    0.03243698924779892,
#    0.034007118083536625,
#    0.03390486817806959,
#    0.03329264186322689,
#    0.0350549453869462,
#    0.03574924357235432,
#    0.041659969836473465,
#    0.0367762167006731,
#    0.03817400150001049,
#    0.03406163677573204,
#    0.03589283488690853,
#    0.04199066665023565,
#    0.037082357332110405,
#    0.03494601882994175,
#    0.03512442950159311,
#    0.037728565745055676,
#    0.0387088879942894,
#    0.03524450398981571,
#    0.0361331682652235,
#    0.03918466065078974,
#    0.03689576778560877,
#    0.03746506106108427,
#    0.0328702088445425,
#    0.035943541675806046,
#    0.03174040466547012,
#    0.03665862325578928,
#    0.030537640675902367,
#    0.033550399355590343,
#    0.03510038275271654,
#    0.037359172478318214,
#    0.03715300094336271,
#    0.03824011702090502,
#    0.03200540505349636,
#    0.03502849582582712,
#    0.033814734779298306,
#    0.03757840860635042,
#    0.03873907960951328,
#    0.03817643504589796,
#    0.03436862304806709,
#    0.0365678146481514,
#    0.035757336765527725,
#    0.03336800541728735,
#    0.03289796505123377,
#    0.03354407474398613,
#    0.036182439886033535,
#    0.03650151379406452,
#    0.03945179283618927,
#    0.034396134316921234,
#    0.03409920260310173,
#    0.034301165491342545,
#    0.03562442399561405,
#    0.03802752401679754,
#    0.037793148308992386,
#    0.036870792508125305]})

# %%
import math
# sample images from the latent space
import matplotlib.pyplot as plt
from matplotlib import gridspec

def stitch_and_show_images(x):
    """
    Stitch image slices horizontally and show the resulting single image.

    :param x: Tensor containing the image slices.
    :param slice_shape: Shape of each slice (channels, height, width).
    """
    x = x.view(-1, *slice_shape)  # Reshape
    x = x.permute(0, 2, 3, 1)     # Reorder dimensions for plotting

    # Concatenate all slices horizontally
    stitched_image = torch.cat(tuple(x), dim=1)
    
    # Calculate the full size for displaying
    full_width = stitched_image.shape[1]
    full_height = stitched_image.shape[0]
    dpi = 80  # Adjust dpi to your screen for accurate sizing (default is usually 80 or 100)
    figsize = full_width / dpi, full_height / dpi
    
    # Convert to numpy and plot
    fig = plt.figure(figsize=figsize, dpi=dpi)
    plt.imshow(stitched_image.cpu().numpy())
    plt.axis('off')
    plt.show()

# %%
for _ in range(3):
    with torch.no_grad():
        noise = torch.randn(SLICES, latent_size).to(DEVICE)
        generated_images = training_model.decoder(noise)
        stitch_and_show_images(generated_images)
